# %%
def calculate_gst(amount, gst_rate):
    sgst = (amount * gst_rate) / 200 
    cgst = (amount * gst_rate) / 200 
    total_tax = sgst + cgst
    total_amount = amount + total_tax
    return sgst, cgst, total_tax, total_amount
print("LULU Hyper Mall")
product = input("Enter product name: ")
product2 = input("Enter product name: ")
amount = float(input("Enter product price (₹): "))
gst_rate = float(input("Enter GST rate (%): "))
sgst, cgst, total_tax, total_amount = calculate_gst(amount, gst_rate)
print("\n--- Bill Details ---")
print(f"Product: {product}")
print(f"Base Price: ₹{amount:.2f}")
print(f"SGST (@{gst_rate/2:.1f}%): ₹{sgst:.2f}")
print(f"CGST (@{gst_rate/2:.1f}%): ₹{cgst:.2f}")
print(f"Total GST: ₹{total_tax:.2f}")
print(f"Grand Total: ₹{total_amount:.2f}")
# Out:
# LULU Hyper Mart
# Enter product name:  pen
# Enter product price (₹):  10
# Enter GST rate (%):  9
# --- Bill Details ---
# Product: pen
# Base Price: ₹10.00
# SGST (@4.5%): ₹0.45
# CGST (@4.5%): ₹0.45
# Total GST: ₹0.90
# Grand Total: ₹10.90
